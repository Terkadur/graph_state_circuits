# %%
from protocol import *
from verify import *

# %%
edges = [(0, 1), (1, 2), (2, 3), (2, 0), (3, 0)]
graph = Graph(n_photons=4, edges=edges)
graph.draw()

# %%
state = StabState(graph=graph)
state.pprint()
# Out:
# 0: +XZZZ
# 1: +ZXZ_
# 2: +ZZXZ
# 3: +Z_ZX

# %%
n_emitters, gen_protocol = protocol(state, recursion_depth=5)

print(f"Verify Protocol: {verify_protocol(state, gen_protocol)}")
protocol_to_stim(gen_protocol).diagram(type='timeline-svg')
# Out:
# Verify Protocol: True
# <svg viewBox="0 0 1056 480"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L1024,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L1024,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L1024,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L1024,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L1024,320 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="320">q4</text>
# <path id="qubit_line:5" d="M64,384 L1024,384 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="384">q5</text>
# </g>
# <rect x="80" y="368" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="384">H</text>
# <rect x="144" y="368" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="160" y="384">S</text>
# <rect x="144" y="304" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="160" y="320">H</text>
# <path d="M224,320 L224,384 " stroke="black"/>
# <circle cx="224" cy="320" r="12" stroke="none" fill="black"/>
# <circle cx="224" cy="384" r="12" stroke="black" fill="white"/>
# <path d="M212,384 L236,384 M224,372 L224,396 " stroke="black"/>
# <path d="M288,64 L288,384 " stroke="black"/>
# <circle cx="288" cy="384" r="12" stroke="none" fill="black"/>
# <circle cx="288" cy="64" r="12" stroke="black" fill="white"/>
# <path d="M276,64 L300,64 M288,52 L288,76 " stroke="black"/>
# <rect x="336" y="48" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="64">X</text>
# <rect x="400" y="48" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="416" y="64">H</text>
# <rect x="464" y="48" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="480" y="64">S</text>
# <rect x="464" y="368" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="480" y="384">H</text>
# <rect x="528" y="368" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="544" y="384">S</text>
# <path d="M544,128 L544,320 " stroke="black"/>
# <circle cx="544" cy="320" r="12" stroke="none" fill="black"/>
# <circle cx="544" cy="128" r="12" stroke="black" fill="white"/>
# <path d="M532,128 L556,128 M544,116 L544,140 " stroke="black"/>
# <rect x="592" y="112" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="608" y="128">H</text>
# <path d="M608,192 L608,384 " stroke="black"/>
# <circle cx="608" cy="384" r="12" stroke="none" fill="black"/>
# <circle cx="608" cy="192" r="12" stroke="black" fill="white"/>
# <path d="M596,192 L620,192 M608,180 L608,204 " stroke="black"/>
# <rect x="656" y="176" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="672" y="192">H</text>
# <rect x="656" y="368" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="672" y="384">H</text>
# <rect x="720" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="24" x="736" y="384" fill="white">MR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="736" y="364">rec[0]</text>
# <rect x="720" y="176" width="96" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="768" y="192">X<tspan baseline-shift="super" font-size="10">rec[0]</tspan></text>
# <path d="M736,256 L736,320 " stroke="black"/>
# <circle cx="736" cy="320" r="12" stroke="none" fill="black"/>
# <circle cx="736" cy="256" r="12" stroke="black" fill="white"/>
# <path d="M724,256 L748,256 M736,244 L736,268 " stroke="black"/>
# <rect x="848" y="240" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="864" y="256">H</text>
# <rect x="848" y="304" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="864" y="320">H</text>
# <rect x="912" y="304" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="24" x="928" y="320" fill="white">MR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="928" y="300">rec[1]</text>
# <rect x="912" y="240" width="96" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="960" y="256">X<tspan baseline-shift="super" font-size="10">rec[1]</tspan></text>
# </svg>
